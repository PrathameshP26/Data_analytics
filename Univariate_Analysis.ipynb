# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('D:\Data_Analytics\\train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## For Categorical Variables
# We use Bar plot and pie plot

# %%
# to get frequency count of people who Survived and who did not survived
sns.barplot(df['Survived'].value_counts())
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
# Frequency count of Categories of embarked
sns.countplot(df['Embarked'].value_counts())
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
df['Sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
df['Sex'].value_counts().plot(kind='pie',autopct='%1.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Pclass'].value_counts().plot(kind='pie',autopct='%1.2f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## For Numerical Data

# %% [markdown]
# ### Histogram

# %%
plt.hist(df['Age'],bins=20)
# Out:
# (array([40., 14., 15., 31., 79., 98., 85., 84., 73., 45., 35., 35., 29.,
#         16., 13., 11.,  4.,  5.,  1.,  1.]),
#  array([ 0.42 ,  4.399,  8.378, 12.357, 16.336, 20.315, 24.294, 28.273,
#         32.252, 36.231, 40.21 , 44.189, 48.168, 52.147, 56.126, 60.105,
#         64.084, 68.063, 72.042, 76.021, 80.   ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# ## Distplot

# %%
sns.displot(df['Age'])

# %%
sns.histplot(df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# ## Box Plot

# %% [markdown]
# To Detect the Outliers we can use Box plot
#
# IQR = Inter Quartile Range
#
# Q1 = 25th percentile
#
# Q3 = 75th percentile
#
# Minimum = Q1-1.5*IQR
#
# Maximum = Q3+1.5*IQR

# %% [markdown]
# There are 3 types of skewness
#
# 1) Symetric Skewed
#
# 2) Positive Skewed
#
# 3) Negatively Skewed

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
df['Age'].skew()
# Out:
# 0.38910778230082704
